# %%
import pandas as pd

dust = pd.read_csv('./data/df_dust_date_all.csv', encoding='euc-kr')

# %%
dust.head()
# Out:
#    Unnamed: 0        측정일시    지역시       SO2        CO        O3       NO2  \
# 0           0  2017-01-01    경기도  0.005185  0.929424  0.007152  0.039614
# 1           1  2017-01-01  서울특별시  0.005474  1.025386  0.003810  0.049406
# 2           2  2017-01-01  인천광역시  0.006541  1.031349  0.012758  0.036274
# 3           3  2017-01-02    경기도  0.005649  0.880707  0.016215  0.037133
# 4           4  2017-01-02  서울특별시  0.006020  0.935619  0.014191  0.045357
#
#          PM10       PM25
# 0   81.229482  56.682143
# 1   80.345455  56.783784
# 2   67.929825  48.496042
# 3  115.142257  75.309609
# 4  114.145038  78.614334

# %%
dust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1914 entries, 0 to 1913
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1914 non-null   int64
#  1   측정일시        1914 non-null   object
#  2   지역시         1914 non-null   object
#  3   SO2         1914 non-null   float64
#  4   CO          1914 non-null   float64
#  5   O3          1914 non-null   float64
#  6   NO2         1914 non-null   float64
#  7   PM10        1914 non-null   float64
#  8   PM25        1914 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 134.7+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax = sns.scatterplot(x='CO', y='PM10', data =dust)

# %%
ax = sns.scatterplot(x='CO', y='PM25', data =dust)

# %%
ax = sns.scatterplot(x='SO2', y='PM10', data =dust)

# %%
ax = sns.scatterplot(x='SO2', y='PM25', data =dust)

# %%
ax = sns.scatterplot(x='NO2', y='PM10', data =dust)

# %%
ax = sns.scatterplot(x='NO2', y='PM25', data =dust)

# %%
ax = sns.scatterplot(x='O3', y='PM10', data =dust)

# %%
ax = sns.scatterplot(x='O3', y='PM25', data =dust)
